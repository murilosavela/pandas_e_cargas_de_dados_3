# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
r = requests.get(url)

# %%
data_json = r.json()
df = pd.DataFrame(data_json['items'])
df
# Out:
#       id_pleito tipo_interessado            interessado  cod_ibge  uf  \
# 0         57189        Município                   Imbé   4310330  RS
# 1         61336        Município            Lima Campos   2106003  MA
# 2         59169        Município                  Butiá   4302709  RS
# 3         42088        Município  São Bernardo do Campo   3548708  SP
# 4         40131        Município               Alvorada   4300604  RS
# ...         ...              ...                    ...       ...  ..
# 4995      19268        Município                 Ampére   4101002  PR
# 4996      22494        Município           Não-Me-Toque   4312658  RS
# 4997      22495        Município        Cruzeiro do Sul   4306205  RS
# 4998       8731        Município                Atibaia   3504107  SP
# 4999      21739        Município                Limeira   3526902  SP
#
#                    num_pvl                                             status  \
# 0     PVL02.003581/2022-35  Encaminhado à PGFN com manifestação técnica fa...
# 1     PVL02.007567/2022-19                                  Deferido (PVL-IF)
# 2     PVL02.005222/2022-12                                           Deferido
# 3     PVL02.008521/2019-11                                           Deferido
# 4     PVL02.007781/2019-61                                           Deferido
# ...                    ...                                                ...
# 4995  00000.000000/2011-12                                           Deferido
# 4996  00000.000000/2031-39                                           Deferido
# 4997  00000.000000/2029-90                                           Deferido
# 4998                  None                                           Deferido
# 4999  00000.000000/2027-26                                           Deferido
#
#               num_processo        data_protocolo  \
# 0     17944.101579/2022-93  2022-06-14T18:35:50Z
# 1                     None                  None
# 2     17944.102122/2022-04  2022-06-27T14:59:57Z
# 3     17944.101228/2020-11  2020-03-12T14:37:43Z
# 4     17944.104162/2019-87  2019-11-26T19:37:03Z
# ...                    ...                   ...
# 4995  17944.000629/2015-97  2015-07-21T03:00:00Z
# 4996  17944.000609/2016-05  2016-04-27T03:00:00Z
# 4997  17944.000608/2016-52  2016-04-27T03:00:00Z
# 4998  17944.000832/2014-82  2014-05-21T03:00:00Z
# 4999  17944.000272/2016-28  2016-03-04T03:00:00Z
#
#                                           tipo_operacao           finalidade  \
# 0     Operação contratual interna (com garantia da U...       Infraestrutura
# 1                           Operação contratual interna       Infraestrutura
# 2                           Operação contratual interna       Infraestrutura
# 3                           Operação contratual interna  PAC 2 - Pró-Moradia
# 4                           Operação contratual interna       Infraestrutura
# ...                                                 ...                  ...
# 4995                        Operação contratual interna       Infraestrutura
# 4996                        Operação contratual interna       Infraestrutura
# 4997                        Operação contratual interna       Infraestrutura
# 4998                        Operação contratual interna       Infraestrutura
# 4999                        Operação contratual interna       Infraestrutura
#
#                           tipo_credor  \
# 0     Instituição Financeira Nacional
# 1     Instituição Financeira Nacional
# 2     Instituição Financeira Nacional
# 3     Instituição Financeira Nacional
# 4     Instituição Financeira Nacional
# ...                               ...
# 4995  Instituição Financeira Nacional
# 4996  Instituição Financeira Nacional
# 4997  Instituição Financeira Nacional
# 4998  Instituição Financeira Nacional
# 4999  Instituição Financeira Nacional
#
#                                                  credor moeda         valor  \
# 0                               Caixa Econômica Federal  Real  1.939677e+07
# 1                               Caixa Econômica Federal  Real  5.000000e+06
# 2                               Caixa Econômica Federal  Real  1.000000e+07
# 3                               Caixa Econômica Federal  Real  1.108261e+08
# 4                               Caixa Econômica Federal  Real  2.000000e+07
# ...                                                 ...   ...           ...
# 4995                   Agência de Fomento do Paraná S/A  Real  2.000000e+06
# 4996  BADESUL Desenvolvimento S.A. - Agência de Fome...  Real  1.000000e+06
# 4997  BADESUL Desenvolvimento S.A. - Agência de Fome...  Real  8.890000e+05
# 4998          Agência de Fomento do Estado de São Paulo  Real  2.799897e+07
# 4999          Agência de Fomento do Estado de São Paulo  Real  7.000000e+06
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 0                    0                      1  29/06/2022
# 1                    0                      1  29/08/2022
# 2                    0                      1  29/06/2022
# 3                    1                      1  19/03/2020
# 4                    1                      0  28/11/2019
# ...                ...                    ...         ...
# 4995                 1                      0  30/07/2015
# 4996                 1                      0  31/05/2016
# 4997                 1                      0  09/06/2016
# 4998                 0                      0  03/06/2014
# 4999                 1                      0  18/04/2016
#
# [5000 rows x 18 columns]

# %%
rio_de_janeiro = df['uf'] == 'RJ'
rio_de_janeiro.sum() #somanto quantas vezes aparece o estado do Rio de Janeiro
# Out:
# 62

# %%
rio_de_janeiro.value_counts() #somanto quantas vezes aparece o estado do Rio de Janeiro, dessa forma também
# Out:
# uf
# False    4938
# True       62
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['id_pleito', 'tipo_interessado', 'interessado', 'cod_ibge', 'uf',
#        'num_pvl', 'status', 'num_processo', 'data_protocolo', 'tipo_operacao',
#        'finalidade', 'tipo_credor', 'credor', 'moeda', 'valor',
#        'pvl_assoc_divida', 'pvl_contradado_credor', 'data_status'],
#       dtype='object')

# %%
# 2) Seu código aqui
Status = df['status'].value_counts().head(3)
Status
# Out:
# status
# Deferido             2578
# Deferido (PVL-IF)    1148
# Arquivado             419
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
df.dtypes
# Out:
# id_pleito                  int64
# tipo_interessado          object
# interessado               object
# cod_ibge                   int64
# uf                        object
# num_pvl                   object
# status                    object
# num_processo              object
# data_protocolo            object
# tipo_operacao             object
# finalidade                object
# tipo_credor               object
# credor                    object
# moeda                     object
# valor                    float64
# pvl_assoc_divida           int64
# pvl_contradado_credor      int64
# data_status               object
# dtype: object

# %%
selecao = df.data_status
ano_status = selecao.str.split('/' ,expand=True)
ano_status = ano_status.loc[:, 2]
ano_status
# Out:
# 0       2022
# 1       2022
# 2       2022
# 3       2020
# 4       2019
#         ...
# 4995    2015
# 4996    2016
# 4997    2016
# 4998    2014
# 4999    2016
# Name: 2, Length: 5000, dtype: object

# %%
# 4) Seu código aqui
ano = pd.Series(ano_status)
ano.value_counts()
# Out:
# 2
# 2008    451
# 2023    416
# 2022    393
# 2019    375
# 2021    329
# 2007    289
# 2010    286
# 2014    245
# 2020    235
# 2012    226
# 2011    211
# 2013    210
# 2009    208
# 2006    202
# 2018    169
# 2004    165
# 2015    122
# 2016    119
# 2017    119
# 2002    111
# 2003     79
# 2005     40
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_dados(uf, tipo_interessado,):
    dados_filtrados = df[(df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)]
    return dados_filtrados

# %%
#teste
uf_consulta = 'RJ'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta
# Out:
#       id_pleito tipo_interessado     interessado  cod_ibge  uf  \
#
Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 4894            Banco Interamericano de Desenvolvimento  Dólar dos EUA
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 271   1.781800e+08                 1                      0  08/10/2009
# 1333  1.326390e+09                 1                      0  02/01/2013
# 2981  3.500000e+07                 1                      0  09/12/2004
# 3338  1.700000e+08                 1                      0  19/04/2006
# 3668  3.500000e+07                 0                      0  20/02/2004
# 3946  5.000000e+07                 0                      0  29/04/2016
# 4894  5.000000e+07                 1                      0  01/04/2010

# %%
resultado_consulta['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    5
# Arquivado                                                1
# Arquivado a pedido                                       1
# Name: count, dtype: int64

# %%
status_mg = resultado_consulta['status'] == 'Arquivado por decurso de prazo'
status_mg.value_counts()
# não tem nenhum status em MG com Arquivado por decurso de prazo
# Out:
# status
# False    7
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Município'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta
# Out:
#       id_pleito tipo_interessado              interessado  cod_ibge  uf  \
# 2         10865        Município                 Barrocas   2903276  BA
# 5         10886        Município                    Irecê   2914604  BA
# 110       10437        Município                   Bonito   2904050  BA
# 196       10167        Município              Santa Luzia   2928059  BA
# 209       10205        Município                   Nazaré   2922508  BA
# ...         ...              ...                      ...       ...  ..
# 4857       9177        Município                  Caetité   2905206  BA
# 4944      61929        Município                 Salvador   2927408  BA
# 4955      61761        Município                   Bonito   2904050  BA
# 4960       6186        Município  Muquém de São Francisco   2922250  BA
# 4990      11879        Município   Luís Eduardo Magalhães   2919553  BA
#
#                    num_pvl                          status  \
# 2                     None                        Deferido
# 5                     None                       Arquivado
# 110                   None                       Arquivado
# 196                   None                       Arquivado
# 209                   None                       Arquivado
# ...                    ...                             ...
# 4857                  None                        Deferido
# 4944  PVL02.007984/2022-53                        Deferido
# 4955  PVL02.008067/2022-96               Deferido (PVL-IF)
# 4960                  None  Arquivado por decurso de prazo
# 4990                  None                        Deferido
#
#               num_processo        data_protocolo                tipo_operacao  \
# 2     17944.001304/2008-01  2008-05-05T03:00:00Z  Operação contratual interna
# 5     17944.001308/2008-81  2008-08-28T03:00:00Z  Operação contratual interna
# 110   17944.001200/2008-98  2008-08-08T03:00:00Z  Operação contratual interna
# 196   17944.001135/2008-09  2008-04-08T03:00:00Z  Operação contratual interna
# 209   17944.001144/2008-91  2008-08-29T03:00:00Z  Operação contratual interna
# ...                    ...                   ...                          ...
# 4857  17944.000919/2013-79  2013-09-02T03:00:00Z  Operação contratual interna
# 4944  17944.104106/2022-48  2022-10-19T15:11:08Z  Operação contratual interna
# 4955                  None                  None  Operação contratual interna
# 4960  17944.000294/2008-88  2008-04-11T03:00:00Z  Operação contratual interna
# 4990  17944.001551/2011-02  2012-08-08T03:00:00Z  Operação contratual interna
#
#                                           finalidade  \
# 2                                     Infraestrutura
# 5                                Caminho da Escola 3
# 110                                   Infraestrutura
# 196                              Caminho da Escola 2
# 209                              Caminho da Escola 2
# ...                                              ...
# 4857  Aquisição de máquinas, equipamentos e veículos
# 4944                                            PMAT
# 4955                                  Infraestrutura
# 4960                               Caminho da Escola
# 4990                        Caminho da Escola 2009 A
#
#                           tipo_credor  \
# 2     Instituição Financeira Nacional
# 5     Instituição Financeira Nacional
# 110   Instituição Financeira Nacional
# 196   Instituição Financeira Nacional
# 209   Instituição Financeira Nacional
# ...                               ...
# 4857  Instituição Financeira Nacional
# 4944  Instituição Financeira Nacional
# 4955  Instituição Financeira Nacional
# 4960  Instituição Financeira Nacional
# 4990  Instituição Financeira Nacional
#
#                                                  credor moeda       valor  \
# 2             Agência de Fomento do Estado da Bahia S/A  Real    500000.0
# 5                                   Banco do Brasil S/A  Real    345400.0
# 110           Agência de Fomento do Estado da Bahia S/A  Real    500000.0
# 196                                 Banco do Brasil S/A  Real    297101.0
# 209                                 Banco do Brasil S/A  Real    540200.0
# ...                                                 ...   ...         ...
# 4857          Agência de Fomento do Estado da Bahia S/A  Real   1800000.0
# 4944  Banco Nacional de Desenvolvimento Econômico e ...  Real  54119000.0
# 4955                                Banco do Brasil S/A  Real   4000000.0
# 4960                                Banco do Brasil S/A  Real    549187.0
# 4990                                Banco do Brasil S/A  Real    882000.0
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 2                    0                      0  30/05/2008
# 5                    0                      0  07/11/2008
# 110                  0                      0  30/10/2008
# 196                  0                      0  13/08/2008
# 209                  0                      0  07/11/2008
# ...                ...                    ...         ...
# 4857                 1                      0  09/10/2013
# 4944                 0                      0  20/10/2022
# 4955                 0                      1  10/11/2022
# 4960                 0                      0  14/05/2008
# 4990                 0                      0  03/09/2012
#
# [210 rows x 18 columns]

# %%
resultado_consulta['status'].value_counts()
# Out:
# status
# Deferido                                                 95
# Deferido (PVL-IF)                                        32
# Arquivado por decurso de prazo                           30
# Arquivado                                                21
# Regularizado                                             11
# Encaminhado à PGFN com manifestação técnica favorável    10
# Arquivado a pedido                                        4
# Pendente de regularização                                 3
# Em retificação pelo credor                                2
# Em retificação pelo interessado                           1
# Indeferido                                                1
# Name: count, dtype: int64

# %%
deferido_ba = resultado_consulta[resultado_consulta['status'] == 'Deferido']
deferido_ba
# Out:
#       id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 2         10865        Município                Barrocas   2903276  BA
# 224       10235        Município  Luís Eduardo Magalhães   2919553  BA
# 225       10239        Município                 Caetité   2905206  BA
# 254        9237        Município                 Boquira   2904100  BA
# 398       30148        Município        Feira de Santana   2910800  BA
# ...         ...              ...                     ...       ...  ..
# 4605      54909        Município              Alagoinhas   2900702  BA
# 4846      64810        Município              Alagoinhas   2900702  BA
# 4857       9177        Município                 Caetité   2905206  BA
# 4944      61929        Município                Salvador   2927408  BA
# 4990      11879        Município  Luís Eduardo Magalhães   2919553  BA
#
#                    num_pvl    status          num_processo  \
# 2                     None  Deferido  17944.001304/2008-01
# 224                   None  Deferido  17944.001151/2010-16
# 225                   None  Deferido  17944.001152/2010-52
# 254                   None  Deferido  17944.000934/2012-36
# 398   PVL02.002213/2018-93  Deferido  17944.109402/2018-59
# ...                    ...       ...                   ...
# 4605  PVL02.000862/2022-36  Deferido  17944.100943/2022-06
# 4846  PVL02.001150/2023-15  Deferido  17944.102229/2023-25
# 4857                  None  Deferido  17944.000919/2013-79
# 4944  PVL02.007984/2022-53  Deferido  17944.104106/2022-48
# 4990                  None  Deferido  17944.001551/2011-02
#
#             data_protocolo                tipo_operacao  \
# 2     2008-05-05T03:00:00Z  Operação contratual interna
# 224   2011-04-11T03:00:00Z  Operação contratual interna
# 225   2011-08-17T03:00:00Z  Operação contratual interna
# 254   2012-05-22T03:00:00Z  Operação contratual interna
# 398   2018-11-14T21:25:48Z  Operação contratual interna
# ...                    ...                          ...
# 4605  2022-03-22T16:22:15Z  Operação contratual interna
# 4846  2023-07-17T20:32:08Z  Operação contratual interna
# 4857  2013-09-02T03:00:00Z  Operação contratual interna
# 4944  2022-10-19T15:11:08Z  Operação contratual interna
# 4990  2012-08-08T03:00:00Z  Operação contratual interna
#
#                                           finalidade  \
# 2                                     Infraestrutura
# 224   Aquisição de máquinas, equipamentos e veículos
# 225   Aquisição de máquinas, equipamentos e veículos
# 254                                   Infraestrutura
# 398                                   Infraestrutura
# ...                                              ...
# 4605                                  Infraestrutura
# 4846                                  Infraestrutura
# 4857  Aquisição de máquinas, equipamentos e veículos
# 4944                                            PMAT
# 4990                        Caminho da Escola 2009 A
#
#                           tipo_credor  \
# 2     Instituição Financeira Nacional
# 224   Instituição Financeira Nacional
# 225   Instituição Financeira Nacional
# 254   Instituição Financeira Nacional
# 398   Instituição Financeira Nacional
# ...                               ...
# 4605  Instituição Financeira Nacional
# 4846  Instituição Financeira Nacional
# 4857  Instituição Financeira Nacional
# 4944  Instituição Financeira Nacional
# 4990  Instituição Financeira Nacional
#
#                                                  credor moeda       valor  \
# 2             Agência de Fomento do Estado da Bahia S/A  Real    500000.0
# 224           Agência de Fomento do Estado da Bahia S/A  Real    130000.0
# 225           Agência de Fomento do Estado da Bahia S/A  Real    130000.0
# 254           Agência de Fomento do Estado da Bahia S/A  Real   1300000.0
# 398                             Caixa Econômica Federal  Real  60000000.0
# ...                                                 ...   ...         ...
# 4605                            Caixa Econômica Federal  Real  49900000.0
# 4846                            Caixa Econômica Federal  Real  30000000.0
# 4857          Agência de Fomento do Estado da Bahia S/A  Real   1800000.0
# 4944  Banco Nacional de Desenvolvimento Econômico e ...  Real  54119000.0
# 4990                                Banco do Brasil S/A  Real    882000.0
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 2                    0                      0  30/05/2008
# 224                  1                      0  29/04/2011
# 225                  1                      0  14/10/2011
# 254                  1                      0  06/07/2012
# 398                  1                      1  21/11/2018
# ...                ...                    ...         ...
# 4605                 0                      1  29/03/2022
# 4846                 0                      1  24/07/2023
# 4857                 1                      0  09/10/2013
# 4944                 0                      0  20/10/2022
# 4990                 0                      0  03/09/2012
#
# [95 rows x 18 columns]

# %%
municipios_solicitacao_deferida = deferido_ba['interessado'].value_counts()
municipios_solicitacao_deferida
#Luís Eduardo Magalhães com maior quantidade de status deferido
# Out:
# interessado
# Luís Eduardo Magalhães    4
# Caetité                   3
# Alagoinhas                3
# Bom Jesus da Lapa         3
# Teixeira de Freitas       2
#                          ..
# Rafael Jambeiro           1
# Macaúbas                  1
# Oliveira dos Brejinhos    1
# Sátiro Dias               1
# Ituberá                   1
# Name: count, Length: 74, dtype: int64

# %%
# 4) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta.to_csv('Solicitações_Bahia.csv')
